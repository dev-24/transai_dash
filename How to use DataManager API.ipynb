# %%
import numpy as np
import pandas as pd
from data_manager import DataManager

# %% [markdown]
# Load the data and initialize the class

# %%
dm = DataManager('./vgsales.csv')

# %% [markdown]
# Use content property to get content

# %%
dm.data
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %% [markdown]
# It's a pandas data frame

# %%
type(dm.data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# get_data is the same, but as method.

# %%
dm.get_data()
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %% [markdown]
# All pandas commnds will work on it. But you don't need to know them :)

# %%
dm.data.shape
# Out:
# (16598, 11)

# %%
dm.data.iloc[0, :]
# Out:
# Rank                     1
# Name            Wii Sports
# Platform               Wii
# Year                  2006
# Genre               Sports
# Publisher         Nintendo
# NA_Sales             41.49
# EU_Sales             29.02
# JP_Sales              3.77
# Other_Sales           8.46
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
dm.column_names
# Out:
# ['Rank',
#  'Name',
#  'Platform',
#  'Year',
#  'Genre',
#  'Publisher',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales']

# %%
dm.filter_by_range(column_name='Year', min_val=2000, max_val=2009, include_max=False)

# %%
dm.data
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# 13        14                                            Wii Fit      Wii
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 19        20       Brain Age: Train Your Brain in Minutes a Day       DS
# 20        21                      Pokemon Diamond/Pokemon Pearl       DS
# 24        25                        Grand Theft Auto: Vice City      PS2
# 25        26                      Pokemon Ruby/Pokemon Sapphire      GBA
# ...

# %%
dm.group_sales_by(column_name='Year')

# %%
dm.data
# Out:
#      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  2000.0     94.49     52.75     42.77        11.62        201.56
# 1  2001.0    173.98     94.89     39.86        22.76        331.47
# 2  2002.0    216.19    109.74     41.76        27.28        395.52
# 3  2003.0    193.59    103.81     34.20        26.01        357.85
# 4  2004.0    222.59    107.32     41.65        47.29        419.31
# 5  2005.0    242.61    121.94     54.28        40.58        459.94
# 6  2006.0    263.12    129.24     73.73        54.43        521.04
# 7  2007.0    312.05    160.50     60.29        77.60        611.13
# 8  2008.0    351.44    184.40     60.26        82.39        678.90

# %%
dm.reset_data()

# %%
dm.filter_by_list(column_name='Platform', filter_list=['PS4'])

# %%
dm.sort(column_name='Global_Sales', ascending=False)

# %%
dm.data
# Out:
#         Rank                                               Name Platform  \
# 33        34                          Call of Duty: Black Ops 3      PS4
# 44        45                                 Grand Theft Auto V      PS4
# 77        78                                            FIFA 16      PS4
# 92        93                       Star Wars Battlefront (2015)      PS4
# 93        94                     Call of Duty: Advanced Warfare      PS4
# 109      110                                          Fallout 4      PS4
# 124      125                                            FIFA 15      PS4
# 154      155                                            Destiny      PS4
# 221      222                                            FIFA 17      PS4
# 236      237                                     The Last of Us      PS4
# 243      244             Uncharted: The Nathan Drake Collection      PS4
# 271      272                         Uncharted 4: A Thief's End      PS4
# ...

# %%
dm.reset_data()

# %% [markdown]
# For group by and sort a list of columns can be passed to sort or group by multiple columns.

# %%
dm.group_sales_by(column_name=['Platform', 'Year'])

# %%
dm.data
# Out:
#     Platform    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0       2600  1980.0     10.59      0.67      0.00         0.12         11.38
# 1       2600  1981.0     33.40      1.96      0.00         0.32         35.77
# 2       2600  1982.0     26.92      1.65      0.00         0.31         28.86
# 3       2600  1983.0      5.44      0.34      0.00         0.06          5.83
# 4       2600  1984.0      0.26      0.01      0.00         0.00          0.27
# 5       2600  1985.0      0.42      0.03      0.00         0.00          0.45
# 6       2600  1986.0      0.63      0.04      0.00         0.00          0.66
# 7       2600  1987.0      1.84      0.09      0.00         0.01          1.98
# 8       2600  1988.0      0.69      0.04      0.00         0.01          0.75
# 9       2600  1989.0      0.59      0.03      0.00         0.01          0.62
# 10       3DO  1994.0      0.00      0.00      0.02         0.00          0.02
# ...

# %%
dm.sort(column_name=['Platform', 'Global_Sales'])

# %%
dm.data.head(20)
# Out:
#    Platform    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4      2600  1984.0      0.26      0.01      0.00         0.00          0.27
# 5      2600  1985.0      0.42      0.03      0.00         0.00          0.45
# 9      2600  1989.0      0.59      0.03      0.00         0.01          0.62
# 6      2600  1986.0      0.63      0.04      0.00         0.00          0.66
# 8      2600  1988.0      0.69      0.04      0.00         0.01          0.75
# 7      2600  1987.0      1.84      0.09      0.00         0.01          1.98
# 3      2600  1983.0      5.44      0.34      0.00         0.06          5.83
# 0      2600  1980.0     10.59      0.67      0.00         0.12         11.38
# 2      2600  1982.0     26.92      1.65      0.00         0.31         28.86
# 1      2600  1981.0     33.40      1.96      0.00         0.32         35.77
# 10      3DO  1994.0      0.00      0.00      0.02         0.00          0.02
# ...
